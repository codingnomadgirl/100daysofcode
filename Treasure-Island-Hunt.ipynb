# %% [markdown]
# Treasure Island Hunt

# %%
# left = """Sorry, you’ve just been robbed. Game Over. Try again."""

# right = """This road is gorgeous! Lush trees, beautiful palms, clear blue ocean. It’s true paradise! Your driver gives you a map and asks whether you want to drive to the little town first or straight to your villa.  Choose town or villa: """

# villa = "Ahhh you should be more adventurous! Villa is not ready until 3pm. Game Over."

# town = """Yay, exploring a new place is so much fun! But you still need to find the treasure before the day is over. Where do you think it is - Cafe, Park or Dancing Studio? Choose cafe, park or studio: """

# cafe = """You know we all love coffee, especially in Colombia! Unfortunately, there’s no treasure here but enjoy your coffee and we will see you soon! Game Over."""

# park = """We love little green spaces all across the island! Unfortunately, the tresure is not here! Have a chat with a few locals and try again. Game Over."""

# studio = "Of course it's in a dancing studio! Congratulations! The heart of Colombia is in the rhythm of music! You win!"


# import webbrowser

# # webbrowser.open("https://www.youtube.com/watch?v=E1oaWvhZ9xE", 2)

# import webbrowser
# webbrowser.open('http://net-informations.com', new=2)


# import requests

# url = input('Webpage to grab source from: https://www.youtube.com/watch?v=E1oaWvhZ9xE ')
# html_output_name = input('Name for html file: ')

# req = requests.get(url, 'html.parser')

# with open(html_output_name, 'w') as f:
#     f.write(req.text)
#     f.close()

# please subscribe my channel - https://bit.ly/2Me2CfB

# import webbrowser
# webbrowser.open('https://bit.ly/2Me2CfB')

# %%
#still need to fix requests import so I could add a link that works at the end.

print('''
*******************************************************************************
          |                   |                  |                     |
 _________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     `"=.|                  |
|___________________|__"=._o`"-._        `"=.______________|___________________
          |                `"=._o`"=._      _`"=._                     |
 _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
|                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
|___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
          |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
 _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
|                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
|___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
____/______/______/___|o;._    "      `".o|o_.--"    ;o;____/______/______/____
/______/______/______/_"=._o--._        ; | ;        ; ;/______/______/______/_
____/______/______/______/__"=._o--._   ;o|o;     _._;o;____/______/______/____
/______/______/______/______/____"=._o._; | ;_.--"o.--"_/______/______/______/_
____/______/______/______/______/_____"=.o|o_.--""___/______/______/______/____
/______/______/______/______/______/______/______/______/______/______/_____ /
*******************************************************************************
''')

import time

left = """Sorry, you’ve just been robbed. Game Over. Try again."""

right = """This road is gorgeous! Lush trees, beautiful palms, clear blue ocean. It’s true paradise! Your driver gives you a map and asks whether you want to drive to the little town first or straight to your villa.  Type 'town' or 'villa': \n"""

villa = "Ahhh you should be more adventurous! Villa is not ready until 3pm. Game Over."

town = """Yay, exploring a new place is so much fun! But you still need to find the treasure before the day is over. Where do you think it is - Cafe, Park or Dancing Studio? Type 'cafe', 'park' or 'studio': \n"""

cafe = """You know we all love coffee, especially in Colombia! Unfortunately, there’s no treasure here but enjoy your coffee and we will see you soon! Game Over."""

park = """We love little green spaces all across the island! Unfortunately, the tresure is not here! Have a chat with a few locals and try again. Game Over."""

studio = "Of course it's in a dancing studio! Congratulations! The heart of Colombia is in the rhythm of music! Here's Your Treasure: /n"


print("Welcome to Treasure Island.")
print("Your mission is to find the treasure.") 
time.sleep(1)
first_choice = input("""You've just landed on a small island in Colombia. You've got a driver and he's waiting for your instructions. Where do you want to go? Type 'left' or 'right'? \n""")

first_choice = first_choice.lower()

if first_choice == "right":
  time.sleep(1)
  second_choice = input(right).lower()
  if second_choice == "town":
    time.sleep(1)
    third_choice = input(town).lower()
    if third_choice == "studio":
      time.sleep(1)
      print(studio)
      url = input('https://www.youtube.com/watch?v=E1oaWvhZ9xE ')
    elif third_choice == "park": 
      time.sleep(1)
      print(park)
    elif third_choice == "cafe":
      time.sleep(1)
      print(cafe)
    else:
      time.sleep(1)
      print("Game over.")
  else:
    time.sleep(1)
    print(villa)
else:
  time.sleep(1)
  print(left)
